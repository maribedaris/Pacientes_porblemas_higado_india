# %% [markdown]
# ## Title
# Descarga de los datos
# ### By:
# Mariana Bedoya Arismendy
#
# ### Date:
# 2026-08-15
#
# ### Description:
#
# En este notebook se realizará la descarga de datos necesarios para el análisis

# %% [markdown]
# ## 📚 Import  libraries

# %%
import sys

print(sys.executable)
# Out:
# /mnt/c/Users/marib/OneDrive/Documentos/Ciencia de datos/Ciencia de datos en producción/Primer_proyecto/Pacientes_porblemas_higado_india/.venv/bin/python

# %%
# base libraries for data science
from pathlib import Path

import pandas as pd

# %% [markdown]
# ## 💾 Load data

# %%
ruta_data = "../../data/01_raw/Pacientes_porblemas_higado_india.csv"

pacientes_df = pd.read_csv(ruta_data, low_memory=False)

pacientes_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Columns: 1024 entries, Age to Unnamed: 1023
# dtypes: float64(931), str(93)
# memory usage: 5.2 MB

# %%
pacientes_df.sample(10)
# Out:
#       Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 586  34.0  Female              0.6               0.1                 161.0
# 245  54.0    Male              0.9               0.2                 290.0
# 402  42.0  Female              0.5               0.1                 162.0
# 355  19.0    Male              1.4               0.8                 178.0
# 269  26.0    Male              0.6               0.1                 110.0
# 571  90.0    Male              1.1               0.3                 215.0
# 201  49.0    Male              0.6               0.1                 218.0
# 54   42.0    Male              8.9               4.5                 272.0
# 126  48.0    Male              5.8               2.5                 802.0
# 439  42.0  Female              0.8               0.2                 168.0
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 586                      15.0                        19.0             6.6
# 245                      15.0                        18.0             6.1
# 402                     155.0                       108.0             8.1
# 355                      13.0                        26.0             8.0
# 269                      15.0                        20.0             2.8
# 571                      46.0                       134.0             6.9
# 201                      50.0                        53.0             5.0
# 54                       31.0                        61.0             5.8
# 126                     133.0                        88.0             6.0
# 439                      25.0                        18.0             6.2
#
#      Albumin  Albumin_and_Globulin_Ratio  ...  Unnamed: 1014  Unnamed: 1015  \
# 586      3.4                         1.0  ...            NaN            NaN
# 245      2.8                         0.8  ...            NaN            NaN
# 402      4.0                         0.9  ...            NaN            NaN
# 355      4.6                         1.3  ...            NaN            NaN
# 269      1.6                         1.3  ...            NaN            NaN
# 571      3.0                         0.7  ...            NaN            NaN
# 201      2.4                         0.9  ...            NaN            NaN
# 54       2.0                         0.5  ...            NaN            NaN
# 126      2.8                         0.8  ...            NaN            NaN
# 439      3.1                         1.0  ...            NaN            NaN
#
#     Unnamed: 1016  Unnamed: 1017  Unnamed: 1018  Unnamed: 1019  Unnamed: 1020  \
# 586           NaN            NaN            NaN            NaN            NaN
# 245           NaN            NaN            NaN            NaN            NaN
# 402           NaN            NaN            NaN            NaN            NaN
# 355           NaN            NaN            NaN            NaN            NaN
# 269           NaN            NaN            NaN            NaN            NaN
# 571           NaN            NaN            NaN            NaN            NaN
# 201           NaN            NaN            NaN            NaN            NaN
# 54            NaN            NaN            NaN            NaN            NaN
# 126           NaN            NaN            NaN            NaN            NaN
# 439           NaN            NaN            NaN            NaN            NaN
#
#      Unnamed: 1021  Unnamed: 1022  Unnamed: 1023
# 586            NaN            NaN            NaN
# 245            NaN            NaN            NaN
# 402            NaN            NaN            NaN
# 355            NaN            NaN            NaN
# 269            NaN            NaN            NaN
# 571            NaN            NaN            NaN
# 201            NaN            NaN            NaN
# 54             NaN            NaN            NaN
# 126            NaN            NaN            NaN
# 439            NaN            NaN            NaN
#
# [10 rows x 1024 columns]

# %% [markdown]
# ## 📊  Data info

# %%
pacientes_df.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio',
#        ...
#        'Unnamed: 1014', 'Unnamed: 1015', 'Unnamed: 1016', 'Unnamed: 1017',
#        'Unnamed: 1018', 'Unnamed: 1019', 'Unnamed: 1020', 'Unnamed: 1021',
#        'Unnamed: 1022', 'Unnamed: 1023'],
#       dtype='str', length=1024)

# %% [markdown]
# ¿Cual es el objetivo del problema?
# ¿Cómo se usará su solución?
# ¿Cuáles son las soluciones actuales (si las hay)?
# ¿Cómo se debe enmarcar este problema (supervisado / no supervisado, en línea / fuera de línea, etc.)
# ¿Cómo se debe medir el desempeño o el rendimiento de la solución, una primera intuicion?
# ¿La medida de desempeño está alineada con el objetivo del problema?
# ¿Cuál sería el desempeño o rendimiento mínimo necesario para alcanzar el objetivo del problema?
# ¿Cuáles son los problemas parecidos? ¿Se puede reutilizar experiencias o herramientas ya creadas?
# ¿Hay experiencia del problema disponible?
# (Importante) ¿Cómo se puede resolver el problema manualmente?
# Hacer un listado de los supuestos que hay hasta este momento.
# Cual es la fuente de los datos?
# Como se actualizan los datos?
# Cada cuanto tiempo se actualizan los datos

# %% [markdown]
# ## 📊 Analysis of Results and Conclusions
#
# Description of the results obtained and if there are conclusions that can be drawn from them.
#
# The analysis of results must be related to the description of the task.
#
# **Note:** An analysis of results does not necessarily lead to conclusions, but to ideas or proposals for future work

# %% [markdown]
# ## 💡 Proposals and Ideas
#
# From the results obtained, what ideas or proposals can be generated to continue with the project

# %% [markdown]
# ## 📖 References
